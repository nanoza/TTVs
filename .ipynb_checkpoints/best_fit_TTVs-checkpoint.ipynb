# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
ttv_fit = pd.read_csv('./SWIFT/koi3678_posterior/MAP_times.txt')

ttv_fit_times = ttv_fit['times(KBJD-277)'].values+277

# %%
ttv_data = pd.read_csv('./TTVs/koi3678.csv')


ttv_data_times =  ttv_data['tts_median [KBJD]']
ttv_data_ttvs =  ttv_data['ttvs_median [min] ']

ttv_data_times_err =  np.array([ttv_data['tts_err lower [days]'],
                                ttv_data['tts_err upper [days]']])

ttv_data_ttvs_err =  np.array([ttv_data['ttvs_err lower [min]'],
                               ttv_data['ttvs_err upper [min]']])

koi3678_period = ttv_data['P_median [days]'][0]
koi3678_t0 = ttv_data['t0_median [KBJD]'][0]

# %%
time = koi3678_t0
ttv_fit_ttvs=[]
for ii in range(0, len(ttv_data_times)):
    ttv_fit_ttvs.append((ttv_fit_times[ii]-time)*24*60)
    print(ttv_fit_times[ii], time)
    print((ttv_fit_times[ii]-time)*24*60)
    print('')
    print(ttv_fit_ttvs)
    print('')
    
    time += koi3678_period
# Out:
# 277.50576740728116 277.50535960053395
# 0.587241715975324
#
# [0.587241715975324]
#
# 438.38797872117937 438.3898322074588
# -2.6690202424197196
#
# [0.587241715975324, -2.6690202424197196]
#
# 599.277774924795 599.2743048143836
# 4.996958992414875
#
# [0.587241715975324, -2.6690202424197196, 4.996958992414875]
#
# 760.1544006026053 760.1587774213085
# -6.302618932659243
#
# [0.587241715975324, -2.6690202424197196, 4.996958992414875, -6.302618932659243]
#
# 921.0456657282936 921.0432500282334
# 3.478608086643362
#
# [0.587241715975324, -2.6690202424197196, 4.996958992414875, -6.302618932659243, 3.478608086643362]
#
# 1081.9293953240913 1081.9277226351583
# 2.4086720635386882
#
# [0.587241715975324, -2.6690202424197196, 4.996958992414875, -6.302618932659243, 3.478608086643362, 2.4086720635386882]
#
# 1242.809393745448 1242.8121952420831
# -4.034155154586188
#
# [0.587241715975324, -2.6690202424197196, 4.996958992414875, -6.302618932659243, 3.478608086643362, 2.4086720635386882, -4.034155154586188]
#
# 1403.701815414665 1403.696667849008
# 7.412494545933441
#
# [0.587241715975324, -2.6690202424197196, 4.996958992414875, -6.302618932659243, 3.478608086643362, 2.4086720635386882, -4.034155154586188, 7.412494545933441]
#
# 1564.5776034939738 1564.5811404559329
# -5.093225221062312
#
# [0.587241715975324, -2.6690202424197196, 4.996958992414875, -6.302618932659243, 3.478608086643362, 2.4086720635386882, -4.034155154586188, 7.412494545933441, -5.093225221062312]

# %%
plt.figure(figsize=[18,10])
plt.errorbar(ttv_data_times, ttv_data_ttvs, yerr = ttv_data_ttvs_err, ls= '', marker='s', color = 'k', ms=7, label='transit model median solution')
plt.plot(ttv_data_times, ttv_fit_ttvs, 'o', ls='-', ms=10, color='#EC8B80', zorder=2, label = 'multiplanet n-body MAP solution')


plt.title('KOI-3762 TTVs', fontsize=45)
plt.ylabel('O-C [min]', fontsize=36)
plt.xlabel('time [KBJD]', fontsize=36)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.legend(fontsize=18)

# %%
ttv_fit_times
# Out:
# array([ 277.50576741,  438.38797872,  599.27777492,  760.1544006 ,
#         921.04566573, 1081.92939532, 1242.80939375, 1403.70181541,
#        1564.57760349])
