# %%
# %matplotlib notebook

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.widgets import Slider, Button

fig, ax = plt.subplots(3,1)
plt.subplots_adjust(left=0.2, bottom=0.1, hspace = 0.3)

test_list = []
s0 = 0

t1 = np.arange(-1, 1, 0.1)
t2 = np.arange(-1, 1, 0.1)
t2 = np.arange(-1, 1, 0.1)

s1 = s0*np.ones(np.shape(t1))
s2 = s0*np.ones(np.shape(t2))
s3 = s0*np.ones(np.shape(t2))

l1, = ax[0].plot(s1, t1, lw=2, color='red')
l2, = ax[1].plot(s2, t2, lw=2, color='red')
l3, = ax[2].plot(s2, t2, lw=2, color='red')



ax[0].set_xlim(0,10)
ax[1].set_xlim(10,20)
ax[2].set_xlim(40,50)

axtime = plt.axes([0.1, 0.1, 0.036, 0.779])
stime = Slider(axtime, 'time', 0, 50., valinit=s0, orientation="vertical")

def update(val):
    l1.set_xdata(val*np.ones(np.shape(t1)))
    l2.set_xdata(val*np.ones(np.shape(t2)))
    l3.set_xdata(val*np.ones(np.shape(t2)))

    fig.canvas.draw_idle()

stime.on_changed(update)

resetax = plt.axes([0.8, 0.025, 0.13, 0.04])
button = Button(resetax, 'save time', color=axcolor, hovercolor='0.975')

def save(event):
    test_list.append(stime.val)
    print(test_list)
    
    #print("Amplitude: ",  sfreq.val)

button.on_clicked(save)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
print(test_list)
# Out:
# [29.104654738981598, 34.45339243688489, 41.00559611681642]

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.widgets import Slider, Button

fig, ax = plt.subplots(3,1)
plt.subplots_adjust(left=0.2, bottom=0.1, hspace = 0.3)

test_list = []
s0 = 0

t1 = np.arange(-1, 1, 0.1)
t2 = np.arange(-1, 1, 0.1)
t2 = np.arange(-1, 1, 0.1)

s1 = s0*np.ones(np.shape(t1))
s2 = s0*np.ones(np.shape(t2))
s3 = s0*np.ones(np.shape(t2))

l1, = ax[0].plot(s1, t1, lw=2, color='red')
l2, = ax[1].plot(s2, t2, lw=2, color='red')
l3, = ax[2].plot(s2, t2, lw=2, color='red')



ax[0].set_xlim(0,10)
ax[1].set_xlim(10,20)
ax[2].set_xlim(40,50)

axtime = plt.axes([0.1, 0.1, 0.036, 0.779])
stime = Slider(axtime, 'time', 0, 50., valinit=s0, orientation="vertical")

def update(val):
    l1.set_xdata(val*np.ones(np.shape(t1)))
    l2.set_xdata(val*np.ones(np.shape(t2)))
    l3.set_xdata(val*np.ones(np.shape(t2)))

    fig.canvas.draw_idle()

stime.on_changed(update)

resetax = plt.axes([0.8, 0.025, 0.13, 0.04])
button = Button(resetax, 'save time', color=axcolor, hovercolor='0.975')

def save(event):
    test_list.append(stime.val)
    print(test_list)
    
    #print("Amplitude: ",  sfreq.val)

button.on_clicked(save)

plt.show()

# %%
print(test_list)
# Out:
# [6.99920654296875, 28.09295654296875, 44.30389404296875, 16.76483154296875]

# %%
import numpy as np
import matplotlib.pyplot  as plt
from   matplotlib.widgets import Slider

plt.close('all')

fig, ax = plt.subplots(nrows=3, ncols=1)
plt.subplots_adjust(bottom=0.25)

########################################
x_time = np.arange(0.0, 100.0, 0.1)

oscil  = np.cos(2 * np.pi * x_time) * np.exp(-x_time)

sin_s  = 2*np.sin(x_time)
cos_s  = np.cos(x_time)
########################################
init = 0.
y = np.arange(-1, 1, 0.0001)
t = init*np.ones(np.shape(y))

l, = ax[0].plot(t, y, lw=2, color='red')
l, = ax[1].plot(t, y, lw=2, color='red')
l, = ax[2].plot(t, y, lw=2, color='red')

########################################
ax[0].set_xlim([0, 10])
ax[1].set_ylim([-2, 2])
ax[2].set_ylim([-1, 1])
########################################
axcolor = 'lightgoldenrodyellow'
axpos = plt.axes([0.2, 0.1, 0.65, 0.03], facecolor=axcolor)
spos = Slider(axfreq, 'Pos', -10, 10, valinit=init)

def update(val):
    pos = spos.val
    ax[2].set_xdata(val*np.ones(np.shape(t)))
    ax[1].set_xdata(val*np.ones(np.shape(t)))
    #ax[1].axis([pos,pos+10,-2,2])
    #ax[2].axis([pos,pos+10,-1,1])
    fig.canvas.draw_idle()

spos.on_changed(update)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
